# %% [markdown]
# # Twitter Collector
#
# ## Setup
# Before you start, you need a few things:
# 1. Twitter OAuth credentials
# 2. plain-text file containing either Twitter handles or user ids (one per line)
# 3. ```settings.cfg``` with proper settings
# 4. virtual environment with all the necessary Python modules - we provide [`environment.yml`](environment.yml) for `conda` users and [`requirements.txt`](requirements.txt) for `pip` users (NOTE: we've tested these only on OS X)
#
# ### Getting Twitter OAuth Credentials
# Here's [Twitter's overview](https://dev.twitter.com/oauth/overview) of the credentials and the process.
#
# ### List of users to fetch
# The scripts can look for either handles or user ids but not both. So, you need to create a plain-text file with one handle or user id per line. We provided [```list_example.txt```](files/list_example.txt) to show you how.
#
# ### Script Settings
# 1. Copy [```settings-example.cfg```](config/settings.cfg) to ```settings.cfg```
# 2. Replace the values in ```settings.cfg``` with settings appropriate for your environment and with your own Twitter credentials
#
# The settings (besides Twitter credentials) are
# - logfile: the name of the file where you want to log the script's output (mostly progress updates)
# - listfile: the name of the file containing your list of handles or ids to fetch
# - outfolder: path to the folder where you want the script to store the JSON(s) returned by Twitter
# - user_id: set to `true` if you provided a list of ids, otherwise leave it as `false`
#
# ## Collect and Cache
# To download the user timelines as JSON files (one per use), run the script below:

# %%
run scripts/twitter_collect.py
# Out:
# getting 11 user timelines

# %% [markdown]
# ## Parse
# Once you have all the JSON files, you can parse the data into some other format that's useful for you. For instance, [Ilan Manor](http://www.qeh.ox.ac.uk/people/arDetails?qeh_id=MAN6IM4365) likes to work in Excel, so we created a parser for him that puts the data he cares about into a CSV Excel can read.

# %%
run scripts/twitter_parse.py
# Out:
# files/out/foreignoffice.0.json
# files/out/foreignoffice.1.json
# files/out/foreignoffice.10.json
# files/out/foreignoffice.11.json
# files/out/foreignoffice.12.json
# files/out/foreignoffice.13.json
# files/out/foreignoffice.14.json
# files/out/foreignoffice.2.json
# files/out/foreignoffice.3.json
# files/out/foreignoffice.4.json
# files/out/foreignoffice.5.json
# files/out/foreignoffice.6.json
# files/out/foreignoffice.7.json
# files/out/foreignoffice.8.json
# files/out/foreignoffice.9.json
# files/out/ForeignOfficeKE.0.json
# files/out/ForeignOfficeKE.1.json
# files/out/ForeignOfficeKE.10.json
# files/out/ForeignOfficeKE.11.json
# files/out/ForeignOfficeKE.12.json
# files/out/ForeignOfficeKE.13.json
# files/out/ForeignOfficeKE.14.json
# files/out/ForeignOfficeKE.2.json
# files/out/ForeignOfficeKE.3.json
# files/out/ForeignOfficeKE.4.json
# files/out/ForeignOfficeKE.5.json
# files/out/ForeignOfficeKE.6.json
# files/out/ForeignOfficeKE.7.json
# files/out/ForeignOfficeKE.8.json
# files/out/ForeignOfficeKE.9.json
# files/out/IndianDiplomacy.0.json
# files/out/IndianDiplomacy.1.json
# files/out/IndianDiplomacy.10.json
# files/out/IndianDiplomacy.11.json
# files/out/IndianDiplomacy.12.json
# files/out/IndianDiplomacy.13.json
# files/out/IndianDiplomacy.14.json
# files/out/IndianDiplomacy.2.json
# files/out/IndianDiplomacy.3.json
# files/out/IndianDiplomacy.4.json
# files/out/IndianDiplomacy.5.json
# files/out/IndianDiplomacy.6.json
# files/out/IndianDiplomacy.7.json
# files/out/IndianDiplomacy.8.json
# files/out/IndianDiplomacy.9.json
# files/out/IsraelMFA.0.json
# files/out/IsraelMFA.1.json
# files/out/IsraelMFA.10.json
# files/out/IsraelMFA.11.json
# files/out/IsraelMFA.12.json
# files/out/IsraelMFA.13.json
# files/out/IsraelMFA.14.json
# files/out/IsraelMFA.2.json
# files/out/IsraelMFA.3.json
